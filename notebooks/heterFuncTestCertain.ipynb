# %%
import time
from copy import deepcopy

import numpy as np

import matplotlib.pyplot as plt

from utils.hmatr import Hmatr
from utils.modelling import modelling

import rpy2.robjects as robjects
import rpy2.robjects.numpy2ri
from rpy2.robjects.packages import importr

import plotly as py
import plotly.express as px
import plotly.graph_objs as go

import openpyxl
import pandas as pd

# %load_ext autoreload
# %load_ext rpy2.ipython
# %autoreload 2

rpy2.robjects.numpy2ri.activate()
utils = importr('utils')
utils.chooseCRANmirror(ind=1)

# utils.install_packages('Rssa')

# library(Rssa)
rssa = importr('Rssa')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# # Инициализация

# %%
N = 700
w1 = 1/10
w2 = 1/10.5
C1 = 1
C2 = 2
phi1 = 0
phi2 = np.pi/4
Q = 301  # 201 номер, значит разладка в ряде будет на 202й точке, если ряд задан с 0.
B = 100
T_ = 100
L = 50
r = 2

method = "svd"

# %%
def plotSeries(s, title='Series', w=16, h=4):
    plt.figure(figsize=(w, h))
    plt.title(title)
    plt.plot(s)

# %% [markdown]
# ## Данные

# %% [markdown]
# Генерируем данные с фиксированным шумом и без.

# %%
seriesPermanent = lambda n: C1*np.sin(2*np.pi*w1*n + phi1) if n < Q-1 else C1*np.sin(2*np.pi*w2*n + phi1)
seriesTemporary = lambda n: C1*np.sin(2*np.pi*w1*n + phi1) if n < Q-1 else C2*np.sin(2*np.pi*w1*n + phi1)
seriesShifted = lambda n: C1*np.sin(2*np.pi*w1*n + phi1) if n < Q-1 else C1*np.sin(2*np.pi*w1*n + phi2)
seriesOutlier = lambda n: C1*np.sin(2*np.pi*w1*n + phi1)

np.random.seed(0)
eps = np.random.randn(N) * 0.5

fPerm = [seriesPermanent(i) for i in range(N)]
fPermNoise = fPerm + eps
hmPerm = Hmatr(fPerm, B, T_, L, neig=r, svdMethod=method)
hmPermNoise = Hmatr(fPermNoise, B, T_, L, neig=r, svdMethod=method)

fTemp = [seriesTemporary(i) for i in range(N)]
fTempNoise = fTemp + eps
hmTemp = Hmatr(fTemp, B, T_, L, neig=r, svdMethod=method)
hmTempNoise = Hmatr(fTempNoise, B, T_, L, neig=r, svdMethod=method)

fShifted = [seriesShifted(i) for i in range(N)]
fShiftedNoise = fShifted + eps
hmShifted = Hmatr(fShifted, B, T_, L, neig=r, svdMethod=method)
hmShiftedNoise = Hmatr(fShiftedNoise, B, T_, L, neig=r, svdMethod=method)


fOutlier = [seriesOutlier(i) for i in range(N)]
fOutlier[Q] = fOutlier[Q] + 10
fOutlierNoise = fOutlier + eps
hmOutlier = Hmatr(fOutlier, B, T_, L, neig=r, svdMethod=method)
hmOutlierNoise = Hmatr(fOutlierNoise, B, T_, L, neig=r, svdMethod=method)

plotSeries(fPermNoise, 'fPermNoise')
plotSeries(fTempNoise, 'fTempNoise')
plotSeries(fShiftedNoise, 'fShiftedNoise')
plotSeries(fOutlierNoise, 'fOutlierNoise')

# %% [markdown]
# Посмотрим на функции разладки

# %%
hmPermNoise.plotHeterFunc('Perm')
hmTempNoise.plotHeterFunc('Temp')
hmShiftedNoise.plotHeterFunc('Shifted')
hmOutlierNoise.plotHeterFunc('Outlier')

# %% [markdown]
# **Стоит заранее отметить, что какие-либо дальнейшие тесты для случаев с временной разладкой и фазовым сдвигом не имеют смысла** - сила исследуемого шума слишком велика для каких-либо разговоров об обнаружении.

# %% [markdown]
# # Моделирование

# %% [markdown]
# Смоделируем случайный шум с дисперсией `0.25` `200` раз на отрезке $[0, \cdots, Q-1]$ и посчитаем характеристики:
# * Средний максимум;
# * Средний 95 процентиль.
#
# **Внимание**, моделирование достаточно долгое. На процессоре `Intel Core i5-7300HQ` моделирование на `200` итерациях `4`х вариантов, определенных выше заняло `30` минут.

# %%
# ?modelling
# Out:
# Signature:
# modelling(
#     dictSeries:dict,
#     iterNum:int,
#     N:int,
#     B:int,
#     T:int,
#     Q:int,
#     L:int,
#     r:int,
#     method:str,
#     destFile:str,
# )
# Docstring:
# :param dict dictSeries: The dictionary where key is the type of series and value is a series. Example: { 'Permanent': [x_1, ..., x_N] }.
# :param int iterNum: Number of iterations for modelling.
# :param int N: The len of series.
# :param int B: The len of base subseries.
# :param int T: The len of test subseries.
# :param int Q: The point of perturbation.
# :param int L: The window len.
# :param int r: Number of eigen vectors.
# :param str method: SVD method.
# :param str destFile: Name of the file for saving results.
# File:      f:\users\ivank\documents\education\magistracy\researchwork\code\notebooks\utils\modelling.py
# Type:      function

# %%
# %%time
modelling(
    dictSeries=dict(zip(['Permanent', 'Temporary', 'Shifted', 'Outlier'], [fPermNoise, fTempNoise, fShiftedNoise, fOutlierNoise])),
    iterNum=200,
    N=N,
    B=B,
    T=T_,
    Q=Q,
    L=L,
    r=r,
    method=method,
    destFile='tables/results.xlsx'
)
# Out:
# Wall time: 29min 36s

# %% [markdown]
# ## Результаты моделирования

# %%
resModelling = pd.read_excel('tables/results.xlsx', sheet_name='Modelling', engine='openpyxl')
resModelling.fillna(' ', inplace=True)
resModelling
# Out:
#         Permanent       row       col       sym      diag
# 0         meanMax   0.59059   0.52587  0.577664  0.556603
# 1   95 procentile  0.583354  0.523551  0.569541  0.553708
# 2
# 3       Temporary       row       col       sym      diag
# 4         meanMax  0.583215  0.526728  0.570537  0.549614
# 5   95 procentile   0.57591  0.524479  0.562019  0.546216
# 6
# 7         Shifted       row       col       sym      diag
# 8         meanMax  0.587149  0.523584  0.574187  0.549744
# 9   95 procentile  0.580319  0.521282  0.566696  0.545878
# 10
# 11        Outlier       row       col       sym      diag
# 12        meanMax  0.581884  0.528694  0.569348  0.548918
# 13  95 procentile  0.575194  0.526477  0.562339   0.54572

# %% [markdown]
# # Оценка скорости возрастания функций разладки

# %% [markdown]
# ## По графикам с дифференцированиям

# %% [markdown]
# Оценим скорость возрастания с помощью дифференцирования подряда с точки $Q$.

# %%
def applyDifferentiation(ser, Q, tail):
    newSer = []
    for i in range(Q-tail, len(ser)-1):
        newSer.append(ser[i+1] - ser[i])
    return newSer

# %% [markdown]
# ### Данные с шумом

# %%
plt.figure(figsize=(16, 4))
plt.plot(applyDifferentiation(hmPerm.getRow(), Q, hmPerm.T), label='row')
plt.plot(applyDifferentiation(hmPerm.getCol(), Q, hmPerm.B), label='col')
plt.plot(applyDifferentiation(hmPerm.getSym(), Q, hmPerm.T), label='sym')
plt.plot(applyDifferentiation(hmPerm.getDiag(), Q, hmPerm.B + hmPerm.T + 1), label='diag')
plt.legend()
plt.show()

# %% [markdown]
# Из графика видно, что хоть и с некоторой задержкой относительно остальных, но **столбцовая** функция разладки возрастает быстрее и сильнее.

# %% [markdown]
# # Оценка момента возрастания функций разладки

# %% [markdown]
# В данной серии экспериментов мы предполагаем что точка разладки известна. Тестирование каких-либо преодолений начинается с точки $Q$ (или с $Q+1$ элемента).

# %%
from utils.fixResultsForHeterFuncs import fixResults

# %% [markdown]
# Начнем с тестирования на данных без шума

# %%
fixResults(
    dict(zip(['Permanent', 'Temporary', 'Shifted', 'Outlier'], [hmPerm, hmTemp, hmShifted, hmOutlier])),
    Q,
    'tables/results.xlsx',
    'tables/results.xlsx',
    'withoutNoise'
)

# %% [markdown]
# С шумом

# %%
fixResults(
    dict(zip(['Permanent', 'Temporary', 'Shifted', 'Outlier'], [hmPermNoise, hmTempNoise, hmShiftedNoise, hmOutlierNoise])),
    Q,
    'tables/results.xlsx',
    'tables/results.xlsx',
    'withNoise'
)

# %%
fixedResult = pd.read_excel('tables/results.xlsx', sheet_name='withoutNoise', engine='openpyxl')
fixedResult.fillna(' ', inplace=True)
fixedResult[:35]
# Out:
#               Permanent   Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0                   Sym      meanMax  95 procentile
# 1   Point of overcoming          100            100
# 2              X[point]            0              0
# 3           X[point+10]            0              0
# 4           X[point+20] -4.44089e-16   -4.44089e-16
# 5           X[point+30]            0              0
# 6
# 7
# 8             Temporary
# 9                   Sym      meanMax  95 procentile
# 10  Point of overcoming          100            100
# 11             X[point]            0              0
# 12          X[point+10]            0              0
# 13          X[point+20] -4.44089e-16   -4.44089e-16
# 14          X[point+30]            0              0
# 15
# 16
# 17              Shifted
# 18                  Sym      meanMax  95 procentile
# 19  Point of overcoming          100            100
# 20             X[point]            0              0
# 21          X[point+10]            0              0
# 22          X[point+20] -4.44089e-16   -4.44089e-16
# 23          X[point+30]            0              0
# 24
# 25
# 26              Outlier
# 27                  Col      meanMax  95 procentile
# 28  Point of overcoming          100            100
# 29             X[point]  2.22045e-16    2.22045e-16
# 30          X[point+10]            0              0
# 31          X[point+20]  2.22045e-16    2.22045e-16
# 32          X[point+30]            0              0
#
#              Unnamed: 4 Unnamed: 5     Unnamed: 6 Unnamed: 7  \
# 0                  Diag    meanMax  95 procentile
# 1   Point of overcoming        338            338
# 2              X[point]          0              0
# 3           X[point+10]          0              0
# 4           X[point+20]          0              0
# 5           X[point+30]          0              0
# 6
# 7
# 8
# 9                   Row    meanMax  95 procentile
# 10  Point of overcoming        100            100
# 11             X[point]          0              0
# 12          X[point+10]          0              0
# 13          X[point+20]          0              0
# 14          X[point+30]          0              0
# 15
# 16
# 17
# 18                  Row    meanMax  95 procentile
# 19  Point of overcoming        100            100
# 20             X[point]          0              0
# 21          X[point+10]          0              0
# 22          X[point+20]          0              0
# 23          X[point+30]          0              0
# 24
# 25
# 26
# 27                 Diag    meanMax  95 procentile
# 28  Point of overcoming        322            321
# 29             X[point]          0              0
# 30          X[point+10]          0              0
# 31          X[point+20]          0              0
# 32          X[point+30]          0              0
#
#              Unnamed: 8   Unnamed: 9    Unnamed: 10 Unnamed: 11  \
# 0                   Row      meanMax  95 procentile
# 1   Point of overcoming          341            340
# 2              X[point]     0.172237       0.172646
# 3           X[point+10]     0.172427       0.172818
# 4           X[point+20]     0.172646       0.172882
# 5           X[point+30]     0.172818       0.172818
# 6
# 7
# 8
# 9                   Col      meanMax  95 procentile
# 10  Point of overcoming          100            100
# 11             X[point]            0              0
# 12          X[point+10]            0              0
# 13          X[point+20]  2.22045e-16    2.22045e-16
# 14          X[point+30]  2.22045e-16    2.22045e-16
# 15
# 16
# 17
# 18                  Col      meanMax  95 procentile
# 19  Point of overcoming          100            100
# 20             X[point]            0              0
# 21          X[point+10]            0              0
# 22          X[point+20]  2.22045e-16    2.22045e-16
# 23          X[point+30]            0              0
# 24
# 25
# 26
# 27                  Row      meanMax  95 procentile
# 28  Point of overcoming          325            325
# 29             X[point]            0              0
# 30          X[point+10]            0              0
# 31          X[point+20]            0              0
# 32          X[point+30]            0              0
#
#             Unnamed: 12  Unnamed: 13    Unnamed: 14
# 0                   Col      meanMax  95 procentile
# 1   Point of overcoming          343            343
# 2              X[point]     0.172777       0.172777
# 3           X[point+10]     0.172777       0.172777
# 4           X[point+20]     0.172777       0.172777
# 5           X[point+30]     0.172777       0.172777
# 6
# 7
# 8
# 9                  Diag      meanMax  95 procentile
# 10  Point of overcoming          201            201
# 11             X[point]            0              0
# 12          X[point+10]   0.00352581     0.00352581
# 13          X[point+20]    0.0184167      0.0184167
# 14          X[point+30]    0.0360284      0.0360284
# 15
# 16
# 17
# 18                 Diag      meanMax  95 procentile
# 19  Point of overcoming          201            201
# 20             X[point]  1.39714e-05    1.39714e-05
# 21          X[point+10]   0.00184148     0.00184148
# 22          X[point+20]   0.00998285     0.00998285
# 23          X[point+30]    0.0250831      0.0250831
# 24
# 25
# 26
# 27                  Sym      meanMax  95 procentile
# 28  Point of overcoming          326            325
# 29             X[point]            0              0
# 30          X[point+10]            0              0
# 31          X[point+20]            0              0
# 32          X[point+30]            0              0

# %% [markdown]
# Видим в таблице что-то странное. Такие результаты получились из за смещения среднего значения функций разладки на промежутке $[0, \cdots, Q]$ из-за шума.

# %% [markdown]
# Посмотрим на результаты данных с шумом (на которых и проводилось моделирование).

# %%
fixedResultNoise = pd.read_excel('tables/results.xlsx', sheet_name='withNoise', engine='openpyxl')
fixedResultNoise.fillna(' ', inplace=True)
fixedResultNoise[:35]
# Out:
#               Permanent Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0                  Diag    meanMax  95 procentile
# 1   Point of overcoming        328            328
# 2              X[point]   0.311525       0.311525
# 3           X[point+10]   0.342855       0.342855
# 4           X[point+20]   0.369607       0.369607
# 5           X[point+30]   0.377604       0.377604
# 6
# 7
# 8             Temporary
# 9                   Sym    meanMax  95 procentile
# 10  Point of overcoming        100            100
# 11             X[point]   0.286147       0.286147
# 12          X[point+10]   0.279671       0.279671
# 13          X[point+20]   0.284891       0.284891
# 14          X[point+30]   0.298389       0.298389
# 15
# 16
# 17              Shifted
# 18                  Sym    meanMax  95 procentile
# 19  Point of overcoming        100            100
# 20             X[point]   0.286147       0.286147
# 21          X[point+10]   0.279671       0.279671
# 22          X[point+20]   0.284891       0.284891
# 23          X[point+30]   0.298389       0.298389
# 24
# 25
# 26              Outlier
# 27                  Col    meanMax  95 procentile
# 28  Point of overcoming        100            100
# 29             X[point]   0.343326       0.343326
# 30          X[point+10]   0.347822       0.347822
# 31          X[point+20]   0.347162       0.347162
# 32          X[point+30]   0.349907       0.349907
#
#              Unnamed: 4 Unnamed: 5     Unnamed: 6 Unnamed: 7  \
# 0                   Row    meanMax  95 procentile
# 1   Point of overcoming        329            328
# 2              X[point]   0.411984       0.407991
# 3           X[point+10]   0.452233       0.448125
# 4           X[point+20]   0.492188       0.488823
# 5           X[point+30]   0.507949       0.507709
# 6
# 7
# 8
# 9                   Row    meanMax  95 procentile
# 10  Point of overcoming        100            100
# 11             X[point]   0.297747       0.297747
# 12          X[point+10]   0.296287       0.296287
# 13          X[point+20]   0.300468       0.300468
# 14          X[point+30]   0.316798       0.316798
# 15
# 16
# 17
# 18                  Row    meanMax  95 procentile
# 19  Point of overcoming        100            100
# 20             X[point]   0.297747       0.297747
# 21          X[point+10]   0.296287       0.296287
# 22          X[point+20]   0.300468       0.300468
# 23          X[point+30]   0.316798       0.316798
# 24
# 25
# 26
# 27                 Diag    meanMax  95 procentile
# 28  Point of overcoming        311            311
# 29             X[point]   0.288347       0.288347
# 30          X[point+10]   0.307206       0.307206
# 31          X[point+20]   0.329034       0.329034
# 32          X[point+30]   0.342177       0.342177
#
#              Unnamed: 8 Unnamed: 9    Unnamed: 10 Unnamed: 11  \
# 0                   Sym    meanMax  95 procentile
# 1   Point of overcoming        331            330
# 2              X[point]   0.303696       0.299213
# 3           X[point+10]   0.338981       0.335835
# 4           X[point+20]   0.355508       0.356549
# 5           X[point+30]   0.345209       0.346811
# 6
# 7
# 8
# 9                   Col    meanMax  95 procentile
# 10  Point of overcoming        100            100
# 11             X[point]   0.343326       0.343326
# 12          X[point+10]   0.347822       0.347822
# 13          X[point+20]   0.347162       0.347162
# 14          X[point+30]   0.349907       0.349907
# 15
# 16
# 17
# 18                  Col    meanMax  95 procentile
# 19  Point of overcoming        100            100
# 20             X[point]   0.343326       0.343326
# 21          X[point+10]   0.347822       0.347822
# 22          X[point+20]   0.347162       0.347162
# 23          X[point+30]   0.349907       0.349907
# 24
# 25
# 26
# 27                  Row    meanMax  95 procentile
# 28  Point of overcoming        315            314
# 29             X[point]    0.32621       0.325354
# 30          X[point+10]   0.341016       0.338864
# 31          X[point+20]   0.368314       0.366659
# 32          X[point+30]   0.385857       0.384703
#
#             Unnamed: 12 Unnamed: 13    Unnamed: 14
# 0                   Col     meanMax  95 procentile
# 1   Point of overcoming         337            337
# 2              X[point]    0.451977       0.451977
# 3           X[point+10]    0.471281       0.471281
# 4           X[point+20]    0.497541       0.497541
# 5           X[point+30]    0.499032       0.499032
# 6
# 7
# 8
# 9                  Diag     meanMax  95 procentile
# 10  Point of overcoming         201            201
# 11             X[point]   0.0993352      0.0993352
# 12          X[point+10]    0.107957       0.107957
# 13          X[point+20]    0.128356       0.128356
# 14          X[point+30]    0.147977       0.147977
# 15
# 16
# 17
# 18                 Diag     meanMax  95 procentile
# 19  Point of overcoming         201            201
# 20             X[point]     0.26463        0.26463
# 21          X[point+10]    0.276248       0.276248
# 22          X[point+20]    0.302564       0.302564
# 23          X[point+30]    0.333276       0.333276
# 24
# 25
# 26
# 27                  Sym     meanMax  95 procentile
# 28  Point of overcoming         316            315
# 29             X[point]    0.311324       0.310733
# 30          X[point+10]    0.326367       0.324263
# 31          X[point+20]    0.353233       0.350755
# 32          X[point+30]    0.375385       0.373543

# %% [markdown]
# Как мы отмечали ранее, для фазового сдвига и временной разладки результаты не несут какой-либо ценности.
#
# В остальных же случаях можно наблюдать какая функция разладки начинает возрастать раньше и по выведенным $4$ точкам можно сравнить скорость возрастания.
#
# Блоки с данными **отсортированы** по возрастанию значения `Point of overcoming` `meanMax`
